# %%
import torch

embed_dim = 96

# %%
query = torch.rand(10, 32, embed_dim)  # (sequence_length, batch_size, embed_dim)
key = torch.rand(10, 32, embed_dim)
value = torch.rand(10, 32, embed_dim)

# %%
query.size()
# Out:
# torch.Size([10, 32, 96])

# %%
assert torch.allclose(query, query)

# %%
import torch.nn as nn
m = nn.Dropout(p=0.2)
input = torch.randn(20, 16)
output = m(input)
output
# Out:
# tensor([[-0.3643, -1.6388, -1.5690,  0.4716, -1.6975, -2.4462,  0.6576,  0.3274,
#          -0.7637, -0.0000,  0.0000,  0.9714,  1.2245,  0.9049,  0.8632, -3.4145],
#         [ 1.6695, -0.1594, -0.0000,  0.0000, -0.0000,  0.0000, -0.7294,  0.0000,
#          -0.0000, -0.9008, -1.2506, -0.8514, -0.0000,  0.0000,  1.7212, -1.0341],
#         [ 0.7569, -0.4770,  0.8922,  0.7695,  1.1727, -1.5981, -0.0000, -0.0000,
#           0.0315,  0.6628,  0.3272,  0.2469,  1.8672, -0.1096,  0.0217,  0.0000],
#         [ 0.3306, -2.1051,  0.4360, -2.1620,  0.4171,  0.2130, -0.7541, -2.1419,
#          -0.0000, -0.0000, -0.9450, -0.7476,  0.5682,  0.0000, -0.0982, -1.5534],
#         [ 0.8688, -0.2898,  1.6872, -0.4748, -1.5593,  0.8393,  1.2187, -1.3400,
#          -0.3942,  0.2540,  1.7891,  0.2213, -0.9282, -1.6419, -0.0937, -1.4894],
#         [-2.0611,  0.0332, -0.0000,  0.5383, -1.8895, -0.0000,  0.8558, -0.0000,
#           0.0000,  1.7382,  0.0000,  1.3584,  1.5629,  0.4445, -1.1035, -0.8314],
#         [-1.3227, -0.4690,  0.2333, -0.0000,  1.5764,  1.0465,  2.7336, -1.0269,
#           0.0690, -0.0000,  0.0000,  1.9238,  0.5815,  0.4572,  1.8637,  1.4997],
#         [ 1.0878,  0.0000,  0.4035, -0.4513,  0.3296,  0.0000, -0.0325, -0.0849,
#           0.9416,  1.3924,  0.0000, -1.6027, -0.9829, -1.1532,  0.0000, -1.8383],
#         [-2.8913,  2.7372,  0.5338,  1.0968,  0.0000, -0.2721, -1.3674, -1.0255,
#          -0.0000, -0.0000,  1.0769, -1.1201,  0.0000,  0.0000,  0.6533,  1.5394],
#         [-0.8144,  0.2107, -0.0480,  0.0000, -0.9182, -0.0941,  0.5733,  0.8149,
#          -1.1116, -1.5292,  0.4892,  0.0000,  1.5861,  0.0000,  0.4154, -0.7609],
#         [ 1.2451,  0.7135,  1.7563, -1.6020,  0.0000,  0.4798, -0.0771,  0.7967,
#           0.0050,  0.8493, -0.0000, -0.4393, -2.5973, -0.7360,  0.9875, -0.6290],
#         [ 0.0000, -0.0000, -1.3553,  0.2782,  0.8433,  2.1949, -0.0000, -0.1798,
#           0.5897,  1.2323,  1.0538,  0.8243,  0.8753, -2.8093, -1.7387, -3.7734],
#         [ 0.1957, -0.9085, -0.0740, -0.7599,  0.2398, -0.0385,  0.0329, -0.0000,
#          -1.6832, -0.6165,  0.0000, -1.5925,  0.7149,  0.0000, -2.0425,  0.8063],
#         [ 3.0610, -0.7076,  2.9741, -2.6094,  0.0000,  0.0000,  1.9633, -0.0000,
#           0.3485, -0.9332, -0.0000, -0.2399, -2.3256,  0.8041, -1.5894, -1.0602],
#         [ 0.0000,  0.4396, -0.0000,  1.7691, -1.5824, -2.0223, -0.0000,  0.8428,
#           2.8509,  0.6653,  0.0229,  0.0000, -1.7727,  2.4164, -0.6117,  0.7221],
#         [-1.2975,  0.0000, -0.5544, -0.1671,  1.2639, -0.5615, -0.2069,  1.5972,
#          -0.3911,  1.6653,  1.4781, -0.6581, -0.1722, -0.0000, -0.7670, -2.0386],
#         [-0.0763,  0.0000, -2.7141,  0.1807,  1.4873, -0.9493, -0.2630,  1.4469,
#          -0.0000,  0.9936, -0.0000, -1.3297, -0.0550,  1.6928,  0.5299,  2.7982],
#         [-0.2357, -0.5326,  0.8621,  0.0935, -1.3572, -0.0000, -1.6174, -0.5234,
#          -2.4163, -1.4231,  1.0228,  0.2579, -1.1304, -0.3836, -0.1661, -0.0000],
#         [-0.2662, -2.1329,  1.1387, -2.0761,  0.1934,  0.0000, -0.2102, -0.0549,
#          -0.6594,  0.5970,  1.4539, -0.8999,  1.4343,  0.0583,  0.0000,  0.0000],
#         [ 2.0503, -1.7411,  0.9456,  2.6492,  0.1965, -1.2037,  0.0594,  1.4839,
#           1.1803, -0.6295, -0.8787, -0.0000, -0.5111,  3.3911,  2.7244,  1.1434]])
